# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch

# %%
df=pd.read_csv('Real_Combine.csv')

# %%
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
X
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM
# 0      7.4   9.8   4.8  1017.6  93.0  0.5   4.3   9.4
# 1      7.8  12.7   4.4  1018.5  87.0  0.6   4.4  11.1
# 2      6.7  13.4   2.4  1019.4  82.0  0.6   4.8  11.1
# 3      8.6  15.5   3.3  1018.7  72.0  0.8   8.1  20.6
# 4     12.4  20.9   4.4  1017.3  61.0  1.3   8.7  22.2
# ...    ...   ...   ...     ...   ...  ...   ...   ...
# 1088  18.1  24.0  11.2  1015.4  56.0  1.8  15.9  25.9
# 1089  17.8  25.0  10.7  1015.8  54.0  2.3   9.4  22.2
# 1090  13.9  24.5  11.4  1015.0  95.0  0.6   8.7  14.8
# 1091  16.3  23.0   9.8  1016.9  78.0  1.1   7.4  16.5
# 1092  16.3  23.4   9.0  1017.3  68.0  1.3   7.8  18.3
#
# [1093 rows x 8 columns]

# %%
y
# Out:
# 0       219.720833
# 1       182.187500
# 2       154.037500
# 3       223.208333
# 4       200.645833
#            ...
# 1088    288.416667
# 1089    256.833333
# 1090    169.000000
# 1091    186.041667
# 1092    185.583333
# Name: PM 2.5, Length: 1093, dtype: float64

# %% [markdown]
# ### Hyperparameters
# 1. How many number of hidden layers we should have?
# 2. How many number of neurons we should have in hidden layers?
# 3. Learning Rate

# %%
def build_model(hp):
    model = keras.Sequential()
    
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation='relu'))
        
    model.add(layers.Dense(1, activation='linear'))
    
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='mean_absolute_error',
        metrics=['mean_absolute_error'])
    
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_error',
    max_trials=5,
    executions_per_trial=3,
    directory='project',
    project_name='Air Quality Index')
# Out:
# 2022-10-11 11:37:09.453149: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
tuner.search(X_train, y_train,
             epochs=5, validation_data=(X_test, y_test))
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/Air Quality Index
# Showing 10 best trials
# Objective(name='val_mean_absolute_error', direction='min')
# Trial summary
# Hyperparameters:
# num_layers: 19
# units_0: 480
# units_1: 352
# learning_rate: 0.01
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# units_9: 32
# units_10: 32
# units_11: 32
# units_12: 32
# units_13: 32
# units_14: 32
# units_15: 32
# units_16: 32
# units_17: 32
# units_18: 32
# Score: nan
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 32
# units_1: 160
# learning_rate: 0.001
# units_2: 32
# units_3: 416
# units_4: 256
# units_5: 480
# units_6: 384
# units_7: 384
# units_8: 256
# units_9: 448
# units_10: 320
# units_11: 512
# units_12: 64
# units_13: 224
# units_14: 320
# units_15: 160
# units_16: 128
# units_17: 64
# units_18: 32
# Score: nan
# Trial summary
# Hyperparameters:
# num_layers: 17
# units_0: 128
# units_1: 320
# learning_rate: 0.0001
# units_2: 416
# units_3: 160
# units_4: 320
# units_5: 128
# units_6: 32
# units_7: 384
# units_8: 384
# units_9: 128
# units_10: 352
# units_11: 128
# units_12: 224
# units_13: 160
# units_14: 352
# units_15: 416
# units_16: 320
# units_17: 192
# units_18: 128
# Score: nan
# Trial summary
# Hyperparameters:
# num_layers: 17
# units_0: 320
# units_1: 448
# learning_rate: 0.001
# units_2: 320
# units_3: 192
# units_4: 128
# units_5: 320
# units_6: 288
# units_7: 192
# units_8: 256
# units_9: 352
# units_10: 32
# units_11: 128
# units_12: 160
# units_13: 416
# units_14: 32
# units_15: 288
# units_16: 64
# units_17: 384
# units_18: 32
# Score: nan
# Trial summary
# Hyperparameters:
# num_layers: 11
# units_0: 224
# units_1: 320
# learning_rate: 0.0001
# units_2: 448
# units_3: 64
# units_4: 224
# units_5: 128
# units_6: 160
# units_7: 512
# units_8: 512
# units_9: 320
# units_10: 256
# units_11: 96
# units_12: 480
# units_13: 352
# units_14: 352
# units_15: 32
# units_16: 224
# units_17: 320
# units_18: 64
# Score: nan

# %%
best_model = tuner.get_best_models(num_models=2)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /var/folders/gj/2w8tst8d3_b8_37zydzd259c0000gn/T/ipykernel_37202/971782313.py in <module>
# ----> 1 best_model = tuner.get_best_models(num_models=2)
#
# /opt/anaconda3/envs/deeplearning/lib/python3.10/site-packages/keras_tuner/engine/tuner.py in get_best_models(self, num_models)
#     389         """
#     390         # Method only exists in this class for the docstring override.
# --> 391         return super(Tuner, self).get_best_models(num_models)
#     392
#     393     def _deepcopy_callbacks(self, callbacks):
#
# /opt/anaconda3/envs/deeplearning/lib/python3.10/site-packages/keras_tuner/engine/base_tuner.py in get_best_models(self, num_models)
#     280         """
#     281         best_trials = self.oracle.get_best_trials(num_models)
# --> 282         models = [self.load_model(trial) for trial in best_trials]
#     283         return models
#     284
#
# /opt/anaconda3/envs/deeplearning/lib/python3.10/site-packages/keras_tuner/engine/base_tuner.py in <listcomp>(.0)
#     280         """
#     281         best_trials = self.oracle.get_best_trials(num_models)
# --> 282         models = [self.load_model(trial) for trial in best_trials]
#     283         return models
#     284
#
# /opt/anaconda3/envs/deeplearning/lib/python3.10/site-packages/keras_tuner/engine/tuner.py in load_model(self, trial)
#     327         best_epoch = trial.best_step
#     328         with maybe_distribute(self.distribution_strategy):
# --> 329             model.load_weights(
#     330                 self._get_checkpoint_fname(trial.trial_id, best_epoch)
#     331             )
#
# /opt/anaconda3/envs/deeplearning/lib/python3.10/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /opt/anaconda3/envs/deeplearning/lib/python3.10/site-packages/tensorflow/python/training/py_checkpoint_reader.py in error_translator(e)
#      29       'Failed to find any '
#      30       'matching files for') in error_message:
# ---> 31     raise errors_impl.NotFoundError(None, None, error_message)
#      32   elif 'Sliced checkpoints are not supported' in error_message or (
#      33       'Data type '
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for project/Air Quality Index/trial_ca162987cbe20a186b8854c40d6f96a5/checkpoints/epoch_None/checkpoint
